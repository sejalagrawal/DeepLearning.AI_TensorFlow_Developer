# %% [markdown]
# <a href="https://colab.research.google.com/github/sejalagrawal/DeepLearning.AI_TensorFlow_Developer/blob/main/C1%3A%20TensorFlow%20for%20DL%20and%20ML/Week1/C1_W1_Lab1_DLAI_pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.8.0

# %%
# Simple sequential model

model = tf.keras. Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error') # sgd-stochastic gradient descent

x= np.array([-1,0,1,2,3,4,5],dtype = float)
y= np.array([-3,-1,1,3,5,7,9],dtype = float)

model.fit(x,y,epochs=1000)

print(model.predict([10]))
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 205ms/step - loss: 61.0099
# Epoch 2/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 42.3816
# Epoch 3/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 29.5601
# Epoch 4/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 20.7330
# Epoch 5/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 14.6537
# Epoch 6/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 10.4646
# Epoch 7/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.5759
# Epoch 8/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.5818
# Epoch 9/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2032
# Epoch 10/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.2481
# Epoch 11/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5845
# Epoch 12/1000
# ...
